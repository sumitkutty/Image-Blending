# %%
import cv2
import imutils
import os
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Functions

# %%
def load_image(path, flag = None):
    '''
    #Loads and converts image to RGB.
    '''
    img = cv2.imread(path, flag)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img


def process_image(img):
    '''
    Processes the image to ease the foreground extraction.
    * thresholding
    * smoothening
    * edge detection
    * contour extraction
    '''
    #to make the inner knife and outer a part of same
    ret, thresh = cv2.threshold(img, 246, 255, cv2.THRESH_BINARY) 
    #to add noise such that the edges are smoother
    blurred = cv2.GaussianBlur(thresh, (11,11), 0) 
    #canny requires grayscale
    gray = cv2.cvtColor(blurred, cv2.COLOR_RGB2GRAY) 
    #Edge detection based on thresholds (500, 200)
    edges = cv2.Canny(gray, 500, 200) 
    #Smoothening little more
    blur = cv2.GaussianBlur(edges, (3,3), 0)
    #Finding Contours
    contours, hierarchy = cv2.findContours(blur, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
    
    return blur, contours #processed image and contours


def viz_images(img1, img2):
    '''
    Visualize two images side by side.
    '''
    fig , (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(10,12))
    ax1.imshow(img1)
    ax2.imshow(img2, cmap = 'gray')
    plt.show()
    
    
def show(img, cnt=None):
    '''
    * Displays an Image
    * Draws contour
    '''
    if cnt is None:
        plt.figure(figsize = (10,12))
        plt.title("Image")
        plt.imshow(img)
        plt.show()
            
    else: #If contour is sent
        c = cv2.drawContours(img, cnt, -1, (0,255,0), 1)
        plt.figure(figsize = (10,12))
        plt.title("Contour")
        plt.imshow(c)
        plt.show()
        
        
def write_image(img, path, names):
    '''
    Writes Image to disk
    '''
    for i in names:
        cv2.imwrite(f"{path}{i}.png", img)
        
        
def convert_to_png(img):
    tmp = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _,alpha = cv2.threshold(tmp,0,255,cv2.THRESH_BINARY)
    b, g, r = cv2.split(img)
    rgba = [b,g,r, alpha]
    dst = cv2.merge(rgba,4)
    return dst


def scalenrotate(dst): 
    '''
    Scales down by a factor and rotates 45 degrees
    '''
    width_resize = int(dst.shape[1] * 0.35)
    dst = imutils.resize(dst, width = width_resize)
    #Rotate and Keep the image within the frame
    rotated = imutils.rotate_bound(dst, 45)
    
    return rotated

# %% [markdown]
# ## Function to Extract Foreground

# %%
def extract_foreground(img, proc_img, contour):
    image_contour = np.copy(img)

    mask = np.zeros_like(proc_img) #create a image with zeros with the same structure

    cv2.fillPoly(mask, [contour], 255)


    res_mask = np.copy(mask)

    res_mask[mask == 0] = cv2.GC_BGD
    res_mask[mask == 255] = cv2.GC_PR_BGD
    res_mask[mask == 255] = cv2.GC_FGD


    mask2 = np.where( 
                (res_mask == cv2.GC_PR_FGD) | (res_mask == cv2.GC_FGD), 255, 0
                 
                 ).astype('uint8')


    #Convert 2D image to 3D image
    new_mask3d = np.repeat(mask2[:, :, np.newaxis],3 , axis = 2)

    mask3d = new_mask3d
    
    #make anything above 0 as white
    mask3d[new_mask3d > 0] = 255.0
    mask3d[mask3d>255] = 255.0

    #final img with white mask on black background
    mask3d = cv2.GaussianBlur(mask3d, (5,5), 0) #white mask on a black image with 3 channels(all 0s)

    foreground = np.copy(img).astype(float)
    foreground[mask2==0] = 0

    #foreground = foreground.astype('uint8')
    
    #foreground = cv2.cvtColor(foreground, cv2.COLOR_RGB2BGR)
    
    
    '''
    convert to png
    scale
    rotate
    '''
    foreground = foreground.astype(np.uint8)
    foreground = cv2.cvtColor(foreground, cv2.COLOR_RGB2RGBA)
    return foreground #, mask3d

# %%
def add_to_background(bgpath,fgpath):
    bg = Image.open(bgpath)
    fg = Image.open(fgpath)
    
    alpha = 0.78
    box = (30,30)
    fg_img_trans = Image.new("RGBA",fg.size)
    fg_img_trans = Image.blend(fg_img_trans,fg,alpha)
    bg.paste(fg_img_trans,box,fg_img_trans)
    
    return bg

# %% [markdown]
# ### Path Declaration and Image name

# %%
bg_imgs = os.listdir('background_images')
threat_imgs = os.listdir('threat_images')

bgimg = 'BAGGAGE_20180811_175323_83216_B_1.jpg'
threatimg = 'BAGGAGE_20170523_094231_80428_B.jpg'

fgimg = '45deg.png'
fgpath = 'threat_masks/' + fgimg


bgpath =     'background_images/' + bgimg
threatpath = 'threat_images/' + threatimg

output_path = 'final_output/'

# %% [markdown]
# ## Main

# %%
for i in range(len(bg_imgs)):
img = load_image(threatpath)
bg= load_image(bgpath)

proc_img, cnts = process_image(img)

contour = max(cnts, key = cv2.contourArea)

fg = extract_foreground(img, proc_img, contour)

final_img = add_to_background(bgpath, fgpath)


show(final_img)

# %%
#final_img.save(output_path+'result1.jpg')

# %% [markdown]
# ## TO-DO

# %%
#mask3d = convert_to_png(mask3d)
#fg = convert_to_png(fg)
#bg = convert_to_png(bg)

# %%
c = load_image('output_images/45deg.png', cv2.IMREAD_UNCHANGED)

c.shape
# Out:
# (255, 255, 3)

# %%
range(len(bg_imgs))
# Out:
# range(0, 5)

# %%
bg_imgs
# Out:
# ['S0320365070_20180821160850_L-12_5.jpg',
#  'BAGGAGE_20180811_175328_83216_A_1.jpg',
#  'S0300542812_20180822020845_L-10_1.jpg',
#  'S0210209058_20180811232942_L-1_1.jpg',
#  'BAGGAGE_20180811_175323_83216_B_1.jpg']
